# %%
from cifkit import CifEnsemble, Cif

ensemble_CCDC = CifEnsemble("tests/data/cif/sources/CCDC")
ensemble_COD = CifEnsemble("tests/data/cif/sources/COD")
ensemble_ICSD = CifEnsemble("tests/data/cif/sources/ICSD")
ensemble_MP = CifEnsemble("tests/data/cif/sources/MP")
ensemble_PCD = CifEnsemble("tests/data/cif/sources/PCD")
ensemble_MS = CifEnsemble("tests/data/cif/sources/MS")

print("ensemble_CCDC:", ensemble_CCDC.CN_unique_values_by_best_methods)
print("ensemble_COD:", ensemble_COD.CN_unique_values_by_best_methods)
print("ensemble_ICSD:", ensemble_ICSD.CN_unique_values_by_best_methods)
print("ensemble_MP:", ensemble_MP.CN_unique_values_by_best_methods)
print("ensemble_PCD:", ensemble_PCD.CN_unique_values_by_best_methods)
print("ensemble_MS:", ensemble_MS.CN_unique_values_by_best_methods)
# Out:
# CIF Preprocessing in tests/data/cif/sources/CCDC begun...
#
# Preprocessing tests/data/cif/sources/CCDC/2294753.cif (1/1)
#
# SUMMARY
# # of files moved to 'error_operations' folder: 0
# # of files moved to 'error_duplicate_labels' folder: 0
# # of files moved to 'error_wrong_loop_value' folder: 0
# # of files moved to 'error_coords' folder: 0
# # of files moved to 'error_invalid_label' folder: 0
# # of files moved to 'error_others' folder: 0
#
# Initializing 1 Cif objects...
# Finished initialization!
#
# CIF Preprocessing in tests/data/cif/sources/COD begun...
#
# Preprocessing tests/data/cif/sources/COD/1010581.cif (1/2)
# Preprocessing tests/data/cif/sources/COD/1523923.cif (2/2)
#
# SUMMARY
# # of files moved to 'error_operations' folder: 0
# # of files moved to 'error_duplicate_labels' folder: 0
# # of files moved to 'error_wrong_loop_value' folder: 0
# # of files moved to 'error_coords' folder: 0
# # of files moved to 'error_invalid_label' folder: 0
# # of files moved to 'error_others' folder: 0
#
# Initializing 2 Cif objects...
# Finished initialization!
#
# CIF Preprocessing in tests/data/cif/sources/ICSD begun...
#
# Preprocessing tests/data/cif/sources/ICSD/EntryWithCollCode52294.cif (1/4)
# Preprocessing tests/data/cif/sources/ICSD/EntryWithCollCode53971.cif (2/4)
# Preprocessing tests/data/cif/sources/ICSD/EntryWithCollCode43054_formatted.cif (3/4)
# Preprocessing tests/data/cif/sources/ICSD/EntryWithCollCode43054.cif (4/4)
#
# SUMMARY
# # of files moved to 'error_operations' folder: 0
# # of files moved to 'error_duplicate_labels' folder: 0
# # of files moved to 'error_wrong_loop_value' folder: 0
# # of files moved to 'error_coords' folder: 0
# # of files moved to 'error_invalid_label' folder: 0
# # of files moved to 'error_others' folder: 0
#
# Initializing 4 Cif objects...
# Finished initialization!
#
# CIF Preprocessing in tests/data/cif/sources/MP begun...
#
# Preprocessing tests/data/cif/sources/MP/LiFeP2O7.cif (1/2)
# Preprocessing tests/data/cif/sources/MP/GaN.cif (2/2)
#
# SUMMARY
# # of files moved to 'error_operations' folder: 0
# # of files moved to 'error_duplicate_labels' folder: 0
# # of files moved to 'error_wrong_loop_value' folder: 0
# # of files moved to 'error_coords' folder: 0
# # of files moved to 'error_invalid_label' folder: 0
# # of files moved to 'error_others' folder: 0
#
# Initializing 2 Cif objects...
# Finished initialization!
#
# CIF Preprocessing in tests/data/cif/sources/PCD begun...
#
# Preprocessing tests/data/cif/sources/PCD/250117.cif (1/1)
#
# SUMMARY
# # of files moved to 'error_operations' folder: 0
# # of files moved to 'error_duplicate_labels' folder: 0
# # of files moved to 'error_wrong_loop_value' folder: 0
# # of files moved to 'error_coords' folder: 0
# # of files moved to 'error_invalid_label' folder: 0
# # of files moved to 'error_others' folder: 0
#
# Initializing 1 Cif objects...
# Finished initialization!
#
# CIF Preprocessing in tests/data/cif/sources/MS begun...
#
# Preprocessing tests/data/cif/sources/MS/U13Rh4.cif (1/1)
#
# SUMMARY
# # of files moved to 'error_operations' folder: 0
# # of files moved to 'error_duplicate_labels' folder: 0
# # of files moved to 'error_wrong_loop_value' folder: 0
# # of files moved to 'error_coords' folder: 0
# # of files moved to 'error_invalid_label' folder: 0
# # of files moved to 'error_others' folder: 0
#
# Initializing 1 Cif objects...
# Finished initialization!
